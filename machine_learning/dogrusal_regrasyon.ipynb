# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('satislar.csv')

# %%
df.head(10)
# Out:
#    Aylar  Satislar
# 0      8   19671.5
# 1     10   23102.5
# 2     11   18865.5
# 3     13   21762.5
# 4     14   19945.5
# 5     19   28321.0
# 6     19    3075.0
# 7     20   27222.5
# 8     20   32222.5
# 9     24   28594.5

# %%
aylar = df[['Aylar']]
satislar = df[['Satislar']]

# %%
np.set_printoptions(suppress=True) # NumPy’nin bilimsel (e+04 gibi) formatla yazmasını engeller.
satislar2 = df.iloc[:,:2].values
satislar2
# Out:
# array([[    8. , 19671.5],
#        [   10. , 23102.5],
#        [   11. , 18865.5],
#        [   13. , 21762.5],
#        [   14. , 19945.5],
#        [   19. , 28321. ],
#        [   19. ,  3075. ],
#        [   20. , 27222.5],
#        [   20. , 32222.5],
#        [   24. , 28594.5],
#        [   25. , 31609. ],
#        [   25. , 27897. ],
#        [   25. , 28478.5],
#        [   26. , 28540.5],
#        [   29. , 30555.5],
#        [   31. , 33969. ],
#        [   32. , 33014.5],
#        [   34. , 41544. ],
#        [   37. , 40681.5],
#        [   37. ,  4697. ],
#        [   42. , 45869. ],
#        [   44. , 49136.5],
#        [   50. , 56906. ],
#        [   54. , 54715.5],
#        [   55. , 52791. ],
#        [   59. , 58484.5],
#        [   59. , 56317.5],
#        [   64. , 61195.5],
#        [   65. , 60936. ]])

# %%
from sklearn.model_selection import train_test_split
                                                    #Bağımsız , Bağımlı
x_train, x_test, y_train, y_test = train_test_split(aylar , satislar
                                                    ,test_size=0.33
                                                    ,random_state=0)

# %%
# df_train = pd.concat([pd.DataFrame(x_train, columns=["Aylar"]), 
#                       pd.DataFrame(y_train, columns=["Satislar"])], axis=1)

# df_test = pd.concat([pd.DataFrame(x_test, columns=["Aylar"]), 
#                      pd.DataFrame(y_test, columns=["Satislar"])], axis=1)

# %%
from sklearn.preprocessing import StandardScaler
# # StandardScaler, verileri z-score standardizasyonuna göre dönüştürür
# # Yani her sütundaki değerler:

# # Ortalama (mean) = 0

# # Standart sapma (std) = 1
# # hale gelir.

# sc = StandardScaler()
# X_train = sc.fit_transform(x_train)
# X_test = sc.fit_transform(x_test)
# Y_train = sc.fit_transform(y_train)
# Y_test = sc.fit_transform(y_test)

# %%
# X_train , X_test

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
tahmin = lr.predict(x_test)
tahmin , y_test
# Out:
# (array([[17657.82918511],
#         [41639.98486299],
#         [50923.3999641 ],
#         [29262.09806151],
#         [28488.48013641],
#         [54791.48958957],
#         [58659.57921503],
#         [54791.48958957],
#         [23846.77258586],
#         [31582.95183678]]),
#      Satislar
#  2    18865.5
#  20   45869.0
#  23   54715.5
#  13   28540.5
#  11   27897.0
#  25   58484.5
#  27   61195.5
#  26   56317.5
#  5    28321.0
#  14   30555.5)

# %%
x_train = x_train.sort_index()
y_train = y_train.sort_index()

# %%
plt.plot(x_train , y_train)
plt.plot(x_test ,lr.predict(x_test), color = 'red')
plt.title('Aylara Göre Satış' , fontsize=15)
plt.xlabel('Aylar' ,fontsize=13)
plt.ylabel('Satışlar' , fontsize=13)
plt.show()
