# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# sns.scatterplot() → İki sayısal değişken arasındaki ilişkiyi nokta grafiği (scatter plot) ile gösterir.
#
# Her nokta, bir veri gözlemini temsil eder.
#
# Özellikle korelasyon veya sınıf ayrımı olup olmadığını anlamak için kullanılır.
#
# 📌 Kısaca:
#
# X ve Y ekseninde iki değişken seçilir → veri noktaları çizilir → ilişki olup olmadığı görsel olarak analiz edilir.

# %%
data = pd.read_excel('mart_train_sample.cvs.xlsx').sample(50)
data.head()
# Out:
#    Item_ID     Item_W     Item_Type    Item_MRP Outlet_ID  Outlet_Year  \
# 25   FDW48  12.254872          Meat  188.210439    OUT046         1988
# 30   FDY07  21.125396   Soft Drinks  210.037074    OUT035         2009
# 6    FDU36  14.330597        Breads   62.460623    OUT013         1988
# 0    FDN27   9.437510   Snack Foods  195.313244    OUT046         1997
# 14   FDU59  20.258653  Baking Goods   65.364400    OUT046         1987
#
#    Outlet_Size Outlet_Location_Type        Sales  Tier
# 25       Small               Tier 2   889.177863     2
# 30        High               Tier 3   953.618749     3
# 6         High               Tier 3  3651.266895     3
# 0        Small               Tier 1   897.085562     1
# 14      Medium               Tier 2  3109.117471     2

# %%
sns.scatterplot(data=data , x='Item_MRP' , y='Sales')
plt.show()

# %%
sns.scatterplot(data=data ,x='Item_MRP' , y='Sales' , s=200,
                color='purple',edgecolor='black',alpha=0.5)
# s=200 tüm noktaların sabit boyutu
plt.show()

# %%
sns.scatterplot(data=data , x='Item_MRP' , y='Sales' , hue='Outlet_Size')
plt.show()

# %%
sns.scatterplot(data=data , x='Item_MRP' , y='Sales' , hue='Outlet_Size',
                style='Outlet_Size')
# style = noktaları şekillere göre ayırır.
plt.show()

# %%
sns.scatterplot(data=data , x='Item_MRP' , y='Sales' , hue='Outlet_Size',
                style='Outlet_Size',markers={'High':"o",
                                             'Small':'*',
                                             'Medium':'v'})
plt.show()

# %%
sns.scatterplot(data=data , x='Item_MRP' , y='Sales',style='Outlet_Size',
                hue='Outlet_Size',
                palette='crest_r',
                markers={'High':"^",
                         "Small":"v",
                         "Medium":"o"})
plt.show()

# %%
sns.scatterplot(data=data , x='Item_MRP' , y='Sales' , hue='Outlet_Size',
                size='Tier',
                sizes=(20,200),
                palette='Purples_r',
                markers={"High":"^","Small":"v","Medium":"o"})
# size= parametresiyle birlikte kullanılır.
# Ama boyutların hangi aralıkta olacağını belirlemek için sizes=(min, max) kullanırsın.
plt.show()

# %%
sns.scatterplot(data=data , x='Item_MRP', y='Sales',hue='Outlet_Size',
                size='Tier',
                sizes=(20,200),
                legend='full',
                palette='Purples_r',
                markers={"High":"^" , "Small":"v" , "Medium":"o"})
# sizes=() -->Bir sütundaki sayısal değerlere göre her noktayı küçükten büyüğe otomatik ölçekler.
# Aynı anda hem hue= hem size= kullanabilirsin; böylece her nokta rengiyle bir kategoriyi, boyutuyla başka bir değeri gösterir.
# legend=	Açıklama kutusu ayarı	legend="brief" veya "full"
plt.show()

# %% [markdown]
# ## Örnek Çalışma

# %%
iris = sns.load_dataset("iris")

sns.scatterplot(
    data=iris,
    x="petal_length",
    y="petal_width",
    hue="species",       # Türlere göre renk ayır
    style="species",     # Türlere göre şekil de ayır
    palette="Set1",      # Renk paleti
    s=70,                # Nokta boyutu
    alpha=0.8            # Hafif şeffaflık
)

plt.title("Iris Veri Seti - Petal Uzunluğu ve Genişliği Scatter Plot")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()
