# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# sns.catplot() Nedir?
# sns.catplot(), kategorik verileri görselleştirmek için kullanılan çok yönlü bir fonksiyondur.
#
# "cat" burada categorical (kategorik) kelimesinin kısaltmasıdır.
#
# Tek bir fonksiyonla stripplot, swarmplot, boxplot, violinplot, barplot, pointplot gibi grafik türlerini çizebilirsin.
#
# Yani çok amaçlı bir "kontrol merkezi" gibi düşünebilirsin.
#
# Özellikle sınıflandırma projelerinde, sınıflara göre değişkenleri analiz etmek için kullanılır.
#
# 🔷 Ne İşe Yarar?
# Kategorilere göre verilerin dağılımını, ortalamasını, yoğunluğunu, sayısını görselleştirirsin.
#
# Model öncesi verinin yapısını anlamana yardımcı olur (feature analysis).
#
# Model sonrası tahmin edilen sınıfların dağılımını karşılaştırabilirsin.
#
# Gruplama ve alt grafikler (facet) ile veriyi detaylı inceleyebilirsin.

# %% [markdown]
# kind=	Grafik türünü seçer ('box', 'violin', 'strip', 'swarm', 'bar', 'point')	kind="box"
#
#
# x=, y=	X ve Y ekseninde hangi değişkenler olacak	x="gender", y="score"
#
#
# hue=	Renklerle 3. bir değişkeni temsil eder	hue="class"
#
#
# col=, row=	Farklı kategoriler için ayrı grafikler çizer (facet)	col="species"
#
#
# height=, aspect=	Grafiğin boyutu ve oranı	height=5, aspect=1.5
#
#
# order=, hue_order=	Kategorilerin gösterim sırası	order=["A", "B", "C"]
#
#
# palette=	Renk paleti belirler	palette="pastel"

# %%
data = pd.read_csv("supermarket_sales.csv")
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.catplot(data=data , x="Payment" , y='Total'
             ,kind='box',
            palette='pastel')
# kind= hangi türde grafik çizeceğimizi belirler
plt.show()
# Out:
# C:\Users\erena\AppData\Local\Temp\ipykernel_16680\2243075910.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=data , x="Payment" , y='Total' ,kind='box',

# %%
sns.catplot(data=data , x='Payment' , y='Total' ,hue='Gender' 
            ,  kind='violin')
plt.show()

# %%
sns.catplot(data=data , x='Payment' , y='Total' ,
            col='Gender' , kind='violin')
# col= veriyi sütunlara (yan yana grafiklere ayırır)
plt.show()

# %%
sns.catplot(data=data , x='Payment' , y='Total',
            col='Gender' , kind='violin' ,row='Customer type' , palette='pastel')
# row= Veriyi satırlara (alt alta grafikleri) ayırır.
plt.show()
# Out:
# C:\Users\erena\AppData\Local\Temp\ipykernel_16680\3671649761.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=data , x='Payment' , y='Total',
