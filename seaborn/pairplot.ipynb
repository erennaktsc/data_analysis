# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# sns.pairplot(), bir veri setindeki sayısal değişkenlerin tüm kombinasyonlarını eşleştirerek grafiklerini çizer.
#
# Her değişken çifti için:
#
# Scatter plot (dağılım grafiği)
#
# Diagonalde histogram veya KDE gösterir.
# 📌 Kısaca:
#
# "Bütün sayısal sütunların birbirleriyle olan ilişkisini tek seferde gösteren çoklu grafik."

# %%
data = sns.load_dataset('iris')

# %%
data.shape
# Out:
# (150, 5)

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=data)
plt.show()

# %%
sns.pairplot(data=data , diag_kind='kde')
plt.show()

# %%
sns.pairplot(data=data , kind='reg')
plt.show()

# %%
sns.pairplot(data=data , hue='species')
plt.show()

# %%
sns.pairplot(data=data , x_vars=['sepal_width' , 'petal_width' , 'petal_length'] ,
             y_vars=['sepal_length'] , diag_kind=None)
plt.show()

# %%
sns.pairplot(data=data , corner=True)
plt.show()

# %%
sns.pairplot(data=data , diag_kws=dict(color='green',kde=True))
plt.show()

# %%
sns.pairplot(data=data , diag_kws=dict(color='green' , kde=True),
             plot_kws=dict(color='orange'))
plt.show()

# %%
sns.pairplot(data=data , diag_kind=dict(color='green' , kde=True),
             plot_kws=dict(color='orange' , marker=10 , s=10))
plt.show()

# %%
l = sns.pairplot(data=data , plot_kws=dict(color='purple'))
l.map_upper(sns.kdeplot)
l.map_lower(sns.kdeplot)
plt.show()

# %%
# Profesyonel pairplot
sns.pairplot(
    data=data,
    hue="species",                # Sınıfları renklendir
    diag_kind="kde",              # Diagonal grafikleri KDE ile çiz
    kind="scatter",               # Alt üçgen scatter olsun
    palette="Set2",               # Renk paleti seçimi
    corner=True,                  # Grafiğin sadece alt üçgenini göster
    plot_kws={"s": 40, "alpha": 0.8, "edgecolor": "gray"},  # Nokta ayarları
    diag_kws={"fill": True, "alpha": 0.6}                   # KDE çizimi için dolgu ve şeffaflık
)

plt.suptitle("Iris Veri Seti - Özellikler Arası Dağılım (Pairplot)", y=1.02, fontsize=14)
plt.show()
