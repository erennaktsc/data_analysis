# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandasda sık kullanılan Fonksiyon ve Metodlar
#
# Bu kısımda pandasda bulunan bazı built-in function(Gömülü Fonksiyon) ve methodları öğreneceğiz. Bu öğrendiklerimiz elbette buz dağının görünen kısmı. Daha gösteremediğim pek çok fonksiyon ve method vardır. Bütün fonksiyon ve methodları görebilmek için bu dökümantasyon incelenebilir. İlerleyen aşamalarda daha fazla fonksiyon ve method göreceğiz. Şidilik göreceğimiz fonksiyon ve methodlar :
#
# apply() method
#
# apply() with a function
#
# apply() with a lambda expression
#
# apply() on multiple columns
#
# describe()
#
# sort_values()
#
# corr()
#
# idxmin and idxmax
#
# value_counts()
#
# replace()
#
# unique and nunique()
#
# map()
#
# duplicated and drop_duplicates()
#
# between()
#
# sample()
#
# nlargest()

# %%
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # .apply() Methodu

# %%
# .apply() methodu bir series ya da datadrame'in sütunlarındaki değelerin hepsine bir anda bir fonksiyon'u uygulamaya yarar.
# Arka planında for döngüsü çalışır dolayısıyla çok hızlı değildir. Performans açısından vektörize edilmiş işlemleri uygulamak daha faydalıdır.
# Özellikle vektörize edilmiş işlemler oldukça hızlı çalışır ve for döngüsü kullanımını minimize eder.
# Ancak diğer taraftan .apply() methodunu kullanmak oldukça okunaklıdır. Başlangıçta kolaydır ve her duruma uygulanabilir. Ancak vektörize işlemler bazı durumlarda yapılamayabilir.

# %%
# Amaç : CC Number sütunundaki değerlerin son 4 rakamını almak ve CC Number sütununu bu şekilde güncellemek.

# %% [markdown]
# ## 1.YOL

# %%
# def son4(x):
#     return str(x)[-4:]

# %%
# df['CC Number'] = df['CC Number'].apply(son4)

# %%
# df.head()

# %% [markdown]
# ## 2.YOL

# %%
# df.head()

# %%
# df['CC Number'] = df['CC Number'].apply(lambda x : str(x)[-4:])

# %%
# df.head()

# %% [markdown]
# ## 3.YOL (Vektorized)(En hızlısı bu)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['CC Number'].astype(str).str[-4:] #Vektörize edilmiş işlem
# astype() metodu, bir sütunun veri tipini (dtype) değiştirmek için kullanılır.
# Out:
# 0      8236
# 1      5212
# 2      0595
# 3      3321
# 4      9910
#        ...
# 239    1889
# 240    6887
# 241    3103
# 242    6392
# 243    5267
# Name: CC Number, Length: 244, dtype: object

# %%
## Amaç : 10 dolardan az ödediyse $ , 10 dolar ile 30 dolar arasında ödediyse $$,
# 30 dolardan fazla ödediyse $$$ işareti bulunan Fiyat Kategorisi adında bir sütun oluşturun

# %% [markdown]
# ## 1.YOL

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def fiyat_kategori(x):
    if x < 10:
        return '$'
    elif 10 <= x < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['Fiyat_Kategorisi'] = df['total_bill'].apply(fiyat_kategori)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham  3560325168603410    Sun2959               $$
# 1      Douglas Tucker  4478071379779230    Sun4608               $$
# 2      Travis Walters  6011812112971322    Sun4458               $$
# 3    Nathaniel Harris  4676137647685994    Sun5260               $$
# 4        Tonya Carter  4832732618637221    Sun2251               $$

# %% [markdown]
# ## 2.YOL

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham  3560325168603410    Sun2959               $$
# 1      Douglas Tucker  4478071379779230    Sun4608               $$
# 2      Travis Walters  6011812112971322    Sun4458               $$
# 3    Nathaniel Harris  4676137647685994    Sun5260               $$
# 4        Tonya Carter  4832732618637221    Sun2251               $$

# %%
df['Fiyat_Kategorisi'] = df['total_bill'].apply(lambda x : '$' if x<10 else('$$' if 10 <= x < 30 else '$$$'))
# lambda yazımında if varsa else de kesinlikle olmalı yoksa hata verir

# %%
df.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 82        21.01  3.00    Male    Yes   Fri  Dinner     2             10.50
# 34        29.80  4.20  Female     No  Thur   Lunch     6              4.97
# 55        25.00  3.75  Female     No   Sun  Dinner     4              6.25
# 231        9.55  1.45    Male     No   Sat  Dinner     2              4.78
# 152       15.81  3.16    Male    Yes   Sat  Dinner     2              7.90
# 68        23.10  4.00    Male    Yes   Sun  Dinner     3              7.70
# 102       19.44  3.00    Male    Yes  Thur   Lunch     2              9.72
# 168       14.48  2.00    Male    Yes   Sun  Dinner     2              7.24
# 145       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 238        7.56  1.44    Male     No  Thur   Lunch     2              3.78
#
#           Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 82        Michael Li  4831801127457917     Fri144               $$
# ...

# %% [markdown]
# ## 3.YOL Vektorized(EN HIZLISII!!!)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham  3560325168603410    Sun2959               $$
# 1      Douglas Tucker  4478071379779230    Sun4608               $$
# 2      Travis Walters  6011812112971322    Sun4458               $$
# 3    Nathaniel Harris  4676137647685994    Sun5260               $$
# 4        Tonya Carter  4832732618637221    Sun2251               $$

# %%
df.drop('Fiyat_Kategorisi' ,axis= 1 , inplace= True)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def fiyat_kategori_vectorized(bill):
    categories = np.full_like(bill , '$' , dtype= 'U3')

    categories[(bill >= 10) & (bill < 30)] = '$$'

    categories[bill >= 30] = '$$$'

    return categories

# %%
df['Fiyat_Kategorisi']= fiyat_kategori_vectorized(df['total_bill'].values)

# %%
df.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 38        18.69  2.31    Male     No   Sat  Dinner     3              6.23
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 185       20.69  5.00    Male     No   Sun  Dinner     5              4.14
# 26        13.37  2.00    Male     No   Sat  Dinner     2              6.68
# 31        18.35  2.50    Male     No   Sat  Dinner     4              4.59
# 121       13.42  1.68  Female     No  Thur   Lunch     2              6.71
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2              6.90
# 151       13.13  2.00    Male     No   Sun  Dinner     2              6.56
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2              8.00
# 46        22.23  5.00    Male     No   Sun  Dinner     2             11.12
#
#           Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 38   Brandon Bradley  4427601595688633    Sat4056               $$
# ...

# %% [markdown]
# # .apply() metodu birdan fazla sütuna aynı anda uygulanabilir

# %% [markdown]
# ## 1.YOL

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham  3560325168603410    Sun2959               $$
# 1      Douglas Tucker  4478071379779230    Sun4608               $$
# 2      Travis Walters  6011812112971322    Sun4458               $$
# 3    Nathaniel Harris  4676137647685994    Sun5260               $$
# 4        Tonya Carter  4832732618637221    Sun2251               $$

# %%
def kareAl(x):
    return x**2

# %%
df[['total_bill' , 'tip']].apply(kareAl)
# Out:
#      total_bill      tip
# 0      288.6601   1.0201
# 1      106.9156   2.7556
# 2      441.4201  12.2500
# 3      560.7424  10.9561
# 4      604.6681  13.0321
# ..          ...      ...
# 239    842.7409  35.0464
# 240    738.7524   4.0000
# 241    513.9289   4.0000
# 242    317.5524   3.0625
# 243    352.6884   9.0000
#
# [244 rows x 2 columns]

# %% [markdown]
# # 2.YOL

# %%
df[['total_bill' , 'tip']].apply(lambda x : x**2)
# Out:
#      total_bill      tip
# 0      288.6601   1.0201
# 1      106.9156   2.7556
# 2      441.4201  12.2500
# 3      560.7424  10.9561
# 4      604.6681  13.0321
# ..          ...      ...
# 239    842.7409  35.0464
# 240    738.7524   4.0000
# 241    513.9289   4.0000
# 242    317.5524   3.0625
# 243    352.6884   9.0000
#
# [244 rows x 2 columns]

# %% [markdown]
# ## 3.YOL Vektorized(En Hızlısı)

# %%
np.square(df[['total_bill' , 'tip']])
# Out:
#      total_bill      tip
# 0      288.6601   1.0201
# 1      106.9156   2.7556
# 2      441.4201  12.2500
# 3      560.7424  10.9561
# 4      604.6681  13.0321
# ..          ...      ...
# 239    842.7409  35.0464
# 240    738.7524   4.0000
# 241    513.9289   4.0000
# 242    317.5524   3.0625
# 243    352.6884   9.0000
#
# [244 rows x 2 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham  3560325168603410    Sun2959               $$
# 1      Douglas Tucker  4478071379779230    Sun4608               $$
# 2      Travis Walters  6011812112971322    Sun4458               $$
# 3    Nathaniel Harris  4676137647685994    Sun5260               $$
# 4        Tonya Carter  4832732618637221    Sun2251               $$

# %%
df.sort_values(by='total_bill')   # Sıralama yapar
# ascending = True oldğu için küçükten büyüğe sıraladı
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51   2.00    Male     No  Thur   Lunch     2              3.76
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
# ...

# %%
df.sort_values(by='total_bill' , ascending= False , inplace= True)  # Büyükten küçüğe sıraladı

# %%
df.head()
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 156       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#           Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 170    Gregory Clark  5473850968388236    Sat1954              $$$
# 212  Alex Williamson      676218815212    Sat4590              $$$
# 59       Brian Ortiz  6596453823950595    Sat8139              $$$
# 156    Ryan Gonzales  3523151482063321    Sun7518              $$$
# 182     Jose Parsons  4112207559459910    Sun2337              $$$

# %%
df.reset_index(inplace= True ,drop= True)

# %%
df.head()
# Out:
#    total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 2       48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 3       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 4       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#         Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark  5473850968388236    Sat1954              $$$
# 1  Alex Williamson      676218815212    Sat4590              $$$
# 2      Brian Ortiz  6596453823950595    Sat8139              $$$
# 3    Ryan Gonzales  3523151482063321    Sun7518              $$$
# 4     Jose Parsons  4112207559459910    Sun2337              $$$

# %%
df.sort_values(['tip' , 'total_bill'] , ascending= False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 0         50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 1         48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 10        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 2         48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 20        34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 131       16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 195       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 240        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 242        5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 243        3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
#
# ...

# %%
df.head(10)
# Out:
#    total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 0       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 1       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 2       48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 3       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 4       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 5       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 6       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 7       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 8       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 9       40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
#
#         Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark  5473850968388236    Sat1954              $$$
# ...

# %%
df['price_per_person'].max()
# Out:
# np.float64(20.27)

# %%
df['price_per_person'].argmax()
# Out:
# np.int64(8)

# %%
df.head()
# Out:
#    total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 2       48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 3       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 4       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#         Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark  5473850968388236    Sat1954              $$$
# 1  Alex Williamson      676218815212    Sat4590              $$$
# 2      Brian Ortiz  6596453823950595    Sat8139              $$$
# 3    Ryan Gonzales  3523151482063321    Sun7518              $$$
# 4     Jose Parsons  4112207559459910    Sun2337              $$$

# %%
df.corr()
# .corr() fonksiyonu, bir DataFrame içindeki sayısal sütunlar arasındaki korelasyon katsayılarını hesaplamak için kullanılır. 
# Korelasyon, değişkenler arasındaki ilişkiyi ölçer ve -1 ile 1 arasında bir değer döndürür:

# 1 → Güçlü pozitif korelasyon (bir değişken artarken diğeri de artar).
# 0 → Hiçbir korelasyon yok (değişkenler arasında bir ilişki yok).
# -1 → Güçlü negatif korelasyon (bir değişken artarken diğeri azalır).
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.corr()
#       2 # .corr() fonksiyonu, bir DataFrame içindeki sayısal sütunlar arasındaki korelasyon katsayılarını hesaplamak için kullanılır.
#       3 # Korelasyon, değişkenler arasındaki ilişkiyi ölçer ve -1 ile 1 arasında bir değer döndürür:
#       4
#       5 # 1 → Güçlü pozitif korelasyon (bir değişken artarken diğeri de artar).
#       6 # 0 → Hiçbir korelasyon yok (değişkenler arasında bir ilişki yok).
#       7 # -1 → Güçlü negatif korelasyon (bir değişken artarken diğeri azalır).
#
# File c:\Users\erena\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
# ...

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df.day.unique()  #bir sütunda kaç farklı değer olduğunu görmek için kullanılır.
#Tekrarlanan değerler bir kez listelenir.
# Out:
# array(['Sat', 'Sun', 'Thur', 'Fri'], dtype=object)

# %%
df.day.nunique()  #Eğer benzersiz değerlerin kaç farklı türde olduğunu öğrenmek istiyorsanız, .nunique() fonksiyonunu kullanabilirsiniz
# Out:
# 4

# %%
# Amaç : sex column'undaki Male olanları 'M' , Female olanları 'F' haline getir.

# %% [markdown]
# ## 1.YOL .apply() Methoduyla

# %%
df.head()
# Out:
#    total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 2       48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 3       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 4       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#         Payer Name         CC Number Payment ID
# 0    Gregory Clark  5473850968388236    Sat1954
# 1  Alex Williamson      676218815212    Sat4590
# 2      Brian Ortiz  6596453823950595    Sat8139
# 3    Ryan Gonzales  3523151482063321    Sun7518
# 4     Jose Parsons  4112207559459910    Sun2337

# %%
df['sex'] = df['sex'].apply(lambda x : 'M' if x == 'Male' else 'F')

# %%
df.head()
# Out:
#    total_bill    tip sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00   M    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00   M     No  Sat  Dinner     4             12.08
# 2       48.27   6.73   M     No  Sat  Dinner     4             12.07
# 3       48.17   5.00   M     No  Sun  Dinner     6              8.03
# 4       45.35   3.50   M    Yes  Sun  Dinner     3             15.12
#
#         Payer Name         CC Number Payment ID
# 0    Gregory Clark  5473850968388236    Sat1954
# 1  Alex Williamson      676218815212    Sat4590
# 2      Brian Ortiz  6596453823950595    Sat8139
# 3    Ryan Gonzales  3523151482063321    Sun7518
# 4     Jose Parsons  4112207559459910    Sun2337

# %% [markdown]
# ## 2.YOL .replace() metoduyla

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['sex'].replace('Female' , 'F' , inplace= True)
df['sex'].replace('Male' , 'M' , inplace= True)

# %%
df.head()
# Out:
#    total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01   F     No  Sun  Dinner     2              8.49
# 1       10.34  1.66   M     No  Sun  Dinner     3              3.45
# 2       21.01  3.50   M     No  Sun  Dinner     3              7.00
# 3       23.68  3.31   M     No  Sun  Dinner     2             11.84
# 4       24.59  3.61   F     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.head()                   # ikisini aynı kodda yazarak F , M yapabiliriz
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['sex'].replace(['Female' ,'Male'] , ['F' , 'M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ## 3.YOL .map() metoduyla

# %%
df['sex'].map({'Female' : 'F',
               'Male' : 'M'})
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
simple_df = pd.DataFrame( data = [[1,2,2,2] , [1,2,3,4] , [1,2,2,2] , [1,2,2,2] ], index = ['a','b','c','d'] , columns = ['col1','col2','col3','col4'])
simple_df
# Out:
#    col1  col2  col3  col4
# a     1     2     2     2
# b     1     2     3     4
# c     1     2     2     2
# d     1     2     2     2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    col1  col2  col3  col4
# a     1     2     2     2
# b     1     2     3     4

# %%
df.head()
# Out:
#    total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 2       48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 3       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 4       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#         Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark  5473850968388236    Sat1954              $$$
# 1  Alex Williamson      676218815212    Sat4590              $$$
# 2      Brian Ortiz  6596453823950595    Sat8139              $$$
# 3    Ryan Gonzales  3523151482063321    Sun7518              $$$
# 4     Jose Parsons  4112207559459910    Sun2337              $$$

# %%
# Amaç : total_bill değerleri 10 ile 20 arasıdnaki satırları getirin.

# %%
df[10 < df['total_bill'] < 20]  # Bu şekilde sorgu yapamıyoruz bunun için .between() methodu var
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3724\733492763.py in ?()
# ----> 1 df[10 < df['total_bill'] < 20]  # Bu şekilde sorgu yapamıyoruz bunun için .between() methodu var
#
# c:\Users\BaTuTo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df['total_bill'].between(10,20)] 
# Default ayarlarda inclusive = 'both' dur. Yani iki taraf da dahildir.
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 97        19.82  3.18    Male     No   Sat  Dinner     2              9.91
# 98        19.81  4.19  Female    Yes  Thur   Lunch     2              9.90
# 99        19.77  2.00    Male     No   Sun  Dinner     4              4.94
# 100       19.65  3.00  Female     No   Sat  Dinner     2              9.82
# 101       19.49  3.51    Male     No   Sun  Dinner     2              9.74
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 222       10.29  2.60  Female     No   Sun  Dinner     2              5.14
# 223       10.27  1.71    Male     No   Sun  Dinner     2              5.14
# 224       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 225       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 226       10.07  1.83  Female     No  Thur   Lunch     1             10.07
#
#            Payer Name         CC Number Payment ID Fiyat_Kategorisi
# ...

# %%
df[df['total_bill'].between(10,20 , inclusive= 'left')]  # 10 dahil 20 dahil değil
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 97        19.82  3.18    Male     No   Sat  Dinner     2              9.91
# 98        19.81  4.19  Female    Yes  Thur   Lunch     2              9.90
# 99        19.77  2.00    Male     No   Sun  Dinner     4              4.94
# 100       19.65  3.00  Female     No   Sat  Dinner     2              9.82
# 101       19.49  3.51    Male     No   Sun  Dinner     2              9.74
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 222       10.29  2.60  Female     No   Sun  Dinner     2              5.14
# 223       10.27  1.71    Male     No   Sun  Dinner     2              5.14
# 224       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 225       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 226       10.07  1.83  Female     No  Thur   Lunch     1             10.07
#
#            Payer Name         CC Number Payment ID Fiyat_Kategorisi
# ...

# %%
df[df['total_bill'].between(10,20 , inclusive= 'right')]  # 20 dahil 10 dahil değil
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 97        19.82  3.18    Male     No   Sat  Dinner     2              9.91
# 98        19.81  4.19  Female    Yes  Thur   Lunch     2              9.90
# 99        19.77  2.00    Male     No   Sun  Dinner     4              4.94
# 100       19.65  3.00  Female     No   Sat  Dinner     2              9.82
# 101       19.49  3.51    Male     No   Sun  Dinner     2              9.74
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 222       10.29  2.60  Female     No   Sun  Dinner     2              5.14
# 223       10.27  1.71    Male     No   Sun  Dinner     2              5.14
# 224       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 225       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 226       10.07  1.83  Female     No  Thur   Lunch     1             10.07
#
#            Payer Name         CC Number Payment ID Fiyat_Kategorisi
# ...

# %%
df.nlargest(5 , 'tip' )  # Tip sütununda en büyük 5 değeri getirir
# Out:
#     total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 0        50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 1        48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 10       39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 2        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 20       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#          Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0     Gregory Clark  5473850968388236    Sat1954              $$$
# 1   Alex Williamson      676218815212    Sat4590              $$$
# 10   Lance Peterson  3542584061609808     Sat239              $$$
# 2       Brian Ortiz  6596453823950595    Sat8139              $$$
# 20   Steven Carlson  3526515703718508   Thur1025              $$$

# %%
df.sort_values('tip' , ascending= False).head()
# Out:
#     total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 0        50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 1        48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 10       39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 2        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 20       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#          Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 0     Gregory Clark  5473850968388236    Sat1954              $$$
# 1   Alex Williamson      676218815212    Sat4590              $$$
# 10   Lance Peterson  3542584061609808     Sat239              $$$
# 2       Brian Ortiz  6596453823950595    Sat8139              $$$
# 20   Steven Carlson  3526515703718508   Thur1025              $$$

# %%
df.nsmallest(3 , 'tip')
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 195       12.60  1.0    Male    Yes  Sat  Dinner     2              6.30
# 240        7.25  1.0  Female     No  Sat  Dinner     1              7.25
# 242        5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
#
#         Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 195  Matthew Myers  3543676378973965    Sat5032               $$
# 240    Terri Jones  3559221007826887    Sat4801                $
# 242   Leah Ramirez  3508911676966392    Fri3780                $

# %%
df.nsmallest(3 , ['tip' , 'total_bill'])
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 243        3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 242        5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
# 240        7.25  1.0  Female     No  Sat  Dinner     1              7.25
#
#         Payer Name         CC Number Payment ID Fiyat_Kategorisi
# 243  Tiffany Brock  4359488526995267    Sat3455                $
# 242   Leah Ramirez  3508911676966392    Fri3780                $
# 240    Terri Jones  3559221007826887    Sat4801                $

# %%
# Done.
